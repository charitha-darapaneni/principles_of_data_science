# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s
import numpy as np
import math

# %%
data = pd.read_csv(r"C:\umkc\courses\pds\assignments\Student performance\data_clean\data_clean.csv")

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
s.barplot(x=data['parental level of education'], y=data['writing score'])
plt.savefig('bar chart 1.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
s.barplot(x=data['test preparation course'], y=data['writing score'])
plt.savefig('bar chart 2.png')
plt.show()

# %%
s.barplot(data=data, x= data['race/ethnicity'], y= data['math score'], hue=data['test preparation course'], palette='pastel')
plt.savefig('bar chart 3.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
s.barplot(data=data, x= data['parental level of education'], y= data['reading score'], hue=data['test preparation course'])
plt.savefig('bar chart 4.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
s.barplot(data=data, x= data['race/ethnicity'], y= data['reading score'], hue=data['gender'])
plt.savefig('bar chart 5.png')
plt.show()
